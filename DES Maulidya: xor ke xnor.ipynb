# %% [markdown]
# <a href="https://colab.research.google.com/github/MaulidyaAyu/kriptografi/blob/main/DES%20Maulidya%3A%20xor%20ke%20xnor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Encryption Standard (DES) - Rounds 16

# %%
# DES Enkripsi

# Function teks ke binary
def text_to_binary(text):
    binary_result = ' '.join(format(ord(char), '08b') for char in text)
    return binary_result.replace(' ', '')

# Function teks ke hexa
def text_to_hex(text):
    hex_result = ''.join(hex(ord(char))[2:] for char in text)
    return hex_result.upper()

#function hexa ke teks
def hex_to_text(hex_string):
    text_result = ''.join(chr(int(hex_string[i:i+2], 16)) for i in range(0, len(hex_string), 2))
    return text_result

# fungsi untuk mengubah binary ke hexa
def bin_to_hex(binary, length):
    bin_to_hex = {"0000" : '0',"0001" : '1',"0010" : '2',"0011" : '3',"0100" : '4',"0101" : '5',"0110" : '6',"0111" : '7',
                  "1000" : '8',"1001" : '9',"1010" : 'A',"1011" : 'B',"1100" : 'C',"1101" : 'D',"1110" : 'E',"1111" : 'F'}
    store = ''
    for i in range(0,length,4):
        store += bin_to_hex[str(binary[i:(i+4)])]
    return store

# fungsi untuk mengubah hexa ke binary
def hex_to_binary(binary, length):
    hex_to_bin = {'0' : "0000", '1' : "0001",'2' : "0010",'3' : "0011",'4' : "0100",'5' : "0101",'6' : "0110",'7' : "0111",
                '8' : "1000",'9' : "1001",'A' : "1010",'B' : "1011",'C' : "1100",'D' : "1101",'E' : "1110",'F' : "1111" }
    store = ''
    for i in range(0,length):
        store += hex_to_bin[str(binary[i])]
    return store

##############################################################################################
############################          YANG DIRUBAH             ###############################
##############################################################################################

# function xnor
def xnor(a,b):
    store = ''
    for i in range(len(a)):
        store += str(int(not(int(a[i]) ^ int(b[i]))))
    return store

# mengubah binary yang tipe datanya string ke int agar bisa diolah nilainya
def bin_to_int(binary_string):
    length = len(binary_string) - 1
    number = 0
    for bin in range(length + 1):
        number += int(binary_string[bin]) * (2 ** (length - bin))
    return number

# mengubah integer ke binary
def int_to_bin(integer):
    return bin(integer)[2:]

# digunakan untuk melakukan shifting sesuai banyaknya iterasi
def shifted(bits, shift):
    return bits[shift:] + bits[:shift]

# 00010001
# contoh shift = 2
#  bits[shift:] = bits[2:]
# mengambil nilai bits selain 2 didepan, 00
# bits[:shift] = bits[:2]
# mengambil nilai bits hanya nilai 2 dari depan, 000100
# return  00 + 000100


#   Defines A Function For Permuting Lists of Binary Using Permutation Lookup Tables
def permute(data, permutation_table, length_of_output):
    permutation = ''
    for i in range(length_of_output):
        permutation += data[permutation_table[i] - 1]
    return permutation

# The Inital and Final Permuttions For The DES Algorithm
def IP(data):
    initial_perm = [58, 50, 42, 34, 26, 18, 10, 2, 60, 52, 44, 36, 28, 20, 12, 4,62, 54, 46, 38, 30, 22, 14, 6, 64, 56, 48, 40, 32, 24, 16, 8,
                    57, 49, 41, 33, 25, 17, 9, 1, 59, 51, 43, 35, 27, 19, 11, 3, 61, 53, 45, 37, 29, 21, 13, 5, 63, 55, 47, 39, 31, 23, 15, 7]
    return permute(data, initial_perm, 64)
def IP_Inverse(data):
    inverse_perm = [40, 8, 48, 16, 56, 24, 64, 32, 39, 7, 47, 15, 55, 23, 63, 31, 38, 6, 46, 14, 54, 22, 62, 30, 37, 5, 45, 13, 53, 21, 61, 29,
                    36, 4, 44, 12, 52, 20, 60, 28, 35, 3, 43, 11, 51, 19, 59, 27, 34, 2, 42, 10, 50, 18, 58, 26, 33, 1, 41, 9, 49, 17, 57, 25 ]
    return permute(data, inverse_perm, 64)


#  Inner functions for bit manipulations in the Feistel Function Stages
def f_expansion(bits):
    # This permutation expands the input to 48 bits and provides a layer of 'confusion'
    expansion_perm = [32, 1 , 2 , 3 , 4 , 5 , 4 , 5, 6 , 7 , 8 , 9 , 8 , 9 , 10, 11, 12, 13, 12, 13, 14, 15, 16, 17,
                      16, 17, 18, 19, 20, 21, 20, 21, 22, 23, 24, 25, 24, 25, 26, 27, 28, 29, 28, 29, 30, 31, 32, 1 ]
    return permute(bits, expansion_perm, 48)

def f_key_mixing(bits, key):
    # This function just xnor's the key into the message
    return xnor(bits, key)

def s_boxes(bits):
    # These substitution boxes are really the core of the DES algorithm, they take six input bits and maps it to 4 output bits
    #       this provides the diffusion necessary to make a secure block cipher (not that DES is secure, because it is not)
    sboxes =   [[[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7], [0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8], [4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0], [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13 ]],
                [[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10], [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5], [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15], [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9 ]],
                [[10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8], [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1], [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7], [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12 ]],
                [[7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15], [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9], [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4], [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14 ]],
                [[2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9], [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6], [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14], [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3 ]],
                [[12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11], [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8], [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6], [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13 ]],
                [[4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1], [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6], [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2], [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12 ]],
                [[13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7], [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2], [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8], [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11 ]]]
    # Split the bytes into 8 substrings, split those substrings into the outer and inner bits,
    #       and use them as indexes for the lookup in the sboxes, convert to binary and pad zeros if necessary
    substituted_string = ''
    for i in range(0,48,6):
        substring = (bits[0:48][i:i+6])
        row = bin_to_int(substring[0] + substring[5])
        column = bin_to_int(substring[1] + substring[2] + substring[3] + substring[4])
        lookup = int_to_bin(sboxes[int(i/6)][row][column])
        if len(lookup) < 4:
            lookup = ((4 - len(lookup)) * '0') + lookup
        substituted_string += lookup

    return substituted_string

# The Feistel function includes a final permutation, for added 'confusion' in each round.
def f_permute(bits):
    p_box = [16, 7, 20, 21, 29, 12, 28, 17, 1, 15, 23, 26, 5, 18, 31, 10, 2, 8, 24, 14, 32, 27, 3, 9, 19, 13, 30, 6, 22, 11, 4, 25]
    return permute(bits, p_box, 32)


# The Feistel Function Called During Encryption and Decryption
def f(bytes, key): # bytes = right_half , 32 bit
    expanded = f_expansion(bytes)
    mixed = f_key_mixing(expanded, key)
    substituted = s_boxes(mixed)
    permutation = f_permute(substituted)
    return permutation


##############################################################################################
############################          YANG DIRUBAH             ###############################
##############################################################################################
def round(left_half, right_half, key):
    print("Sebelum di XNOR kan:",  left_half, f(right_half, key))
    new_right_half = xnor(left_half, f(right_half, key))
    print("Hasil setelah XNOR:", new_right_half)
    return right_half, new_right_half


#############################################################
# The Key Schedule Generator
#   This function generates the sixteen subkeys for DES
#############################################################
def generate_keys(intitial_state): # inputan berupa hex
    # check apakah panjang bit nya 64 key
    if len(intitial_state) != 64:
      # check jika panjangnya 16 , kemungkinan menggunakan hexa dan mengubah ke binary
        if len(intitial_state) == 16:
            intitial_state = hex_to_binary(intitial_state, 16)
        else:
            return 'ERROR MESSAGE NOT PROPER SIZE'

    pc_1 = [57, 49, 41, 33, 25, 17, 9, 1, 58, 50, 42, 34, 26, 18, 10, 2, 59, 51, 43, 35, 27, 19, 11, 3, 60, 52, 44, 36,
            63, 55, 47, 39, 31, 23, 15, 7, 62, 54, 46, 38, 30, 22, 14, 6, 61, 53, 45, 37, 29, 21, 13, 5, 28, 20, 12, 4]
    pc_2 = [14, 17, 11, 24, 1, 5, 3, 28, 15, 6, 21, 10, 23, 19, 12, 4, 26, 8, 16, 7, 27, 20, 13, 2, 41,
            52, 31, 37, 47, 55, 30, 40, 51, 45, 33, 48, 44, 49, 39, 56, 34, 53, 46, 42, 50, 36, 29, 32 ]
    # di mutasi ke pc1
    permuted = permute(intitial_state, pc_1, 56)

    key_schedule = []
    left_half, right_half = permuted[0:28], permuted[28:56]
    for loop in range(16):
        print("Sebelum shifting:", left_half, right_half)
        if loop in {0, 1, 8, 15}:
            left_half, right_half = shifted(left_half, 1), shifted(right_half, 1)
        else:
            left_half, right_half = shifted(left_half, 2), shifted(right_half, 2)
        print("Sesudah shifting:", left_half, right_half)

        key_schedule.append(permute((left_half + right_half), pc_2, 48))

    return key_schedule



####################################################################
#   THE MAIN ENCRYPTION FUNCTION FOR DES
#       This function encrypts a block of 64 bits using
#       a 64 bit key (this is supposed to include parity bits)
####################################################################
def encrypt(message, key):
    if len(message) != 64:
        if len(message) == 16:
            message = hex_to_binary(message, 16)
        else:
            return 'ERROR MESSAGE NOT PROPER SIZE'

    key_schedule = generate_keys(key)

    print('Data Being Encrypted: ', bin_to_hex(message, 64))
    perm = IP(message)
    print('After Initial Permutation: ', bin_to_hex(perm, 64))

    left_half, right_half = perm[0:32], perm[32:64]

    print(' ' * 20, 'Left Half  ', 'Right Half ', 'Sub Key  ')
    for loop in range(16):
        left_half, right_half = round(left_half, right_half, key_schedule[loop])
        # if loop == 15: # For Some Reason The Algorithm Doesn't Swap The Last Two Keys So This Switches Them Back
        #     buffer = left_half
        #     left_half = right_half
        #     right_half = buffer
        # print('Round: ', loop + 1, ' ', bin_to_hex(left_half, 32), ' ', bin_to_hex(right_half, 32), ' ', bin_to_hex(key_schedule[loop], 48))
        print('Round: ', loop + 1, ' ', left_half, ' ', right_half, ' ', key_schedule[loop])
        if loop == 15:
          print('Round: ', "Swap", ' ', right_half, ' ', left_half, ' ', key_schedule[loop])

    cyphertext = IP_Inverse(right_half + left_half)
    return cyphertext

####################################################################
#   THE MAIN DECRYPTION FUNCTION FOR DES
#       This function decrypts a block of 64 bits using
#       a 64 bit key (this is supposed to include parity bits)
#       It is the same as encrypton algorithm but  with an upside
#       down key schedule.
####################################################################
def decrypt(message, key):
    if len(message) != 64:
        if len(message) == 16:
            message = hex_to_binary(message, 16)
        else:
            return 'ERROR MESSAGE NOT PROPER SIZE'
    key_schedule = generate_keys(key)
    print('Data Being Encrypted:      ', bin_to_hex(message, 64))
    perm = IP(message)
    print('After Initial Permutation: ', bin_to_hex(perm, 64))
    left_half, right_half = perm[0:32], perm[32:64]
    print(' ' * 20, 'Left Half  ',' ' * 20, 'Right Half ',' ' * 20, 'Sub Key  ')
    for loop in range(16):
        left_half, right_half = round(left_half, right_half, key_schedule[15 - loop])
        # if loop == 15: # For Some Reason The Algorithm Doesn't Swap The Last Two Keys So This Switches Them Back
        #     buffer = left_half
        #     left_half = right_half
        #     right_half = buffer
        # print('Round: ', loop + 1, ' ', bin_to_hex(left_half, 32), ' ', bin_to_hex(right_half, 32), ' ', bin_to_hex(key_schedule[loop], 48))
        print('Round: ', loop + 1, ' ', left_half , ' ', right_half, ' ', key_schedule[loop] )

    cyphertext = IP_Inverse(right_half + left_half)

    return cyphertext

# Membuat teks menjadi 8 huruf dan dimasukan kedalam array
def modif_plain(par):
    while len(par) % 8 != 0:
        par += "-"
    par_arr = [par[i:i+8] for i in range(0, len(par), 8)]
    return par_arr

def modif_cipher(par):
    while len(par) % 64 != 0:
        par += "-"
    par_arr = [par[i:i+64] for i in range(0, len(par), 64)]
    return par_arr



def encrypt_print(plain , key):
  hasil_encrypt = []
  hasil_encrypt_hexa= []

  hex_key = text_to_hex(key)

  for i in plain:
    e = encrypt(text_to_binary(i), hex_key)
    encrypt_hexa =  bin_to_hex(''.join(e) , 64)
    encrypt_text =  hex_to_text(bin_to_hex(''.join(e) , 64))
    hasil_encrypt.append(e)
    hasil_encrypt_hexa.append(encrypt_hexa)


  print("Hasil enkrip dalam bentuk biner = " ,  ''.join(hasil_encrypt))
  print("Hasil enkrip dalam bentuk hexa =  " , ''.join(hasil_encrypt_hexa) )

  return hasil_encrypt

def decrypt_print(chiper , key):
  hex_key = text_to_hex(key)
  # print(cipher_modif)
  hasil_decrpyt = []
  for x in chiper:
    hasil_decrpyt.append(hex_to_text( bin_to_hex(decrypt(x, hex_key), 64)))

  print("Plain Text =" ,''.join(hasil_decrpyt).rstrip('-'))
  return hasil_decrpyt

def main():
  while True:
        print("\nPilihlah salah satu dari pilihan berikut:")
        print("1. Encrypt")
        print("2. Decrypt")
        print("3. Keluar dari program")
        choice = input("Masukkan pilihan Anda: ")

        if choice == '1':
            plain_text = input("Masukkan plain text untuk dienkripsi :  ")
            plain_modif = modif_plain(plain_text)
            key = input("Masukan key text ( 64 bit / 8 huruf ) : ")
            hasil = encrypt_print(plain_modif , key)

        elif choice == '2':
            cipher_text = input("Masukkan cipher text (dalam binary): ")
            key = input("Masukkan kunci: ")
            cipher_modif = modif_cipher(cipher_text)
            hasil = decrypt_print(cipher_modif , key)

        elif choice == '3':
            print("Terima kasih, program selesai.")
            break
        else:
            print("Pilihan tidak valid. Silakan pilih 1, 2, atau 3.")



main()
# Out:
# Pilihlah salah satu dari pilihan berikut:
# 1. Encrypt
# 2. Decrypt
# 3. Keluar dari program
# Sesudah shifting: 0000000111111111111111101000 0000000001011010101100101000
# Sebelum shifting: 0000000111111111111111101000 0000000001011010101100101000
# Sesudah shifting: 0000001111111111111111010000 0000000010110101011001010000
# Sebelum shifting: 0000001111111111111111010000 0000000010110101011001010000
# Sesudah shifting: 0000111111111111111101000000 0000001011010101100101000000
# Sebelum shifting: 0000111111111111111101000000 0000001011010101100101000000
# Sesudah shifting: 0011111111111111110100000000 0000101101010110010100000000
# Sebelum shifting: 0011111111111111110100000000 0000101101010110010100000000
# Sesudah shifting: 1111111111111111010000000000 0010110101011001010000000000
# Sebelum shifting: 1111111111111111010000000000 0010110101011001010000000000
# Sesudah shifting: 1111111111111101000000000011 1011010101100101000000000000
# Sebelum shifting: 1111111111111101000000000011 1011010101100101000000000000
# Sesudah shifting: 1111111111110100000000001111 1101010110010100000000000010
# Sebelum shifting: 1111111111110100000000001111 1101010110010100000000000010
# Sesudah shifting: 1111111111010000000000111111 0101011001010000000000001011
# Sebelum shifting: 1111111111010000000000111111 0101011001010000000000001011
# Sesudah shifting: 1111111110100000000001111111 1010110010100000000000010110
# Sebelum shifting: 1111111110100000000001111111 1010110010100000000000010110
# Sesudah shifting: 1111111010000000000111111111 1011001010000000000001011010
# Sebelum shifting: 1111111010000000000111111111 1011001010000000000001011010
# Sesudah shifting: 1111101000000000011111111111 1100101000000000000101101010
# Sebelum shifting: 1111101000000000011111111111 1100101000000000000101101010
# Sesudah shifting: 1110100000000001111111111111 0010100000000000010110101011
# Sebelum shifting: 1110100000000001111111111111 0010100000000000010110101011
# Sesudah shifting: 1010000000000111111111111111 1010000000000001011010101100
# Sebelum shifting: 1010000000000111111111111111 1010000000000001011010101100
# Sesudah shifting: 1000000000011111111111111110 1000000000000101101010110010
# Sebelum shifting: 1000000000011111111111111110 1000000000000101101010110010
# Sesudah shifting: 0000000001111111111111111010 0000000000010110101011001010
# Sebelum shifting: 0000000001111111111111111010 0000000000010110101011001010
# Sesudah shifting: 0000000011111111111111110100 0000000000101101010110010100
# Data Being Encrypted:  6166692D2D2D2D2D
# After Initial Permutation:  0700FAFD00FFFC02
#                      Left Half   Right Half  Sub Key
# Sebelum di XNOR kan: 00000111000000001111101011111101 01000000001000011110110110111000
# Hasil setelah XNOR: 10111000110111101110100010111010
# Round:  1   00000000111111111111110000000010   10111000110111101110100010111010   111000001011111001100110100010011101000001000000
# Sebelum di XNOR kan: 00000000111111111111110000000010 10000001011101101000001000111100
# Hasil setelah XNOR: 01111110011101101000000111000001
# Round:  2   10111000110111101110100010111010   01111110011101101000000111000001   111100001011011001110110010110010000101000111000
# Sebelum di XNOR kan: 10111000110111101110100010111010 10011001000001101010000111110001
# Hasil setelah XNOR: 11011110001001111011011010110100
# Round:  3   01111110011101101000000111000001   11011110001001111011011010110100   111001001101011001110110000100010101100000011000
# Sebelum di XNOR kan: 01111110011101101000000111000001 10011010011001110100101100000010
# Hasil setelah XNOR: 00011011111011100011010100111100
# Hasil enkrip dalam bentuk hexa =   DC32AA02D5BEDEB3943847BCCB54EE30
#
# Pilihlah salah satu dari pilihan berikut:
# 1. Encrypt
# 2. Decrypt
# 3. Keluar dari program
# Sebelum shifting: 0000000011111111111111110100 0000000000101101010110010100
# Sesudah shifting: 0000000111111111111111101000 0000000001011010101100101000
# Sebelum shifting: 0000000111111111111111101000 0000000001011010101100101000
# Sesudah shifting: 0000001111111111111111010000 0000000010110101011001010000
# Sebelum shifting: 0000001111111111111111010000 0000000010110101011001010000
# Sesudah shifting: 0000111111111111111101000000 0000001011010101100101000000
# Sebelum shifting: 0000111111111111111101000000 0000001011010101100101000000
# Sesudah shifting: 0011111111111111110100000000 0000101101010110010100000000
# Sebelum shifting: 0011111111111111110100000000 0000101101010110010100000000
# Sesudah shifting: 1111111111111111010000000000 0010110101011001010000000000
# Sebelum shifting: 1111111111111111010000000000 0010110101011001010000000000
# Sesudah shifting: 1111111111111101000000000011 1011010101100101000000000000
# Sebelum shifting: 1111111111111101000000000011 1011010101100101000000000000
# Sesudah shifting: 1111111111110100000000001111 1101010110010100000000000010
# Sebelum shifting: 1111111111110100000000001111 1101010110010100000000000010
# Sesudah shifting: 1111111111010000000000111111 0101011001010000000000001011
# Sebelum shifting: 1111111111010000000000111111 0101011001010000000000001011
# Sesudah shifting: 1111111110100000000001111111 1010110010100000000000010110
# Sebelum shifting: 1111111110100000000001111111 1010110010100000000000010110
# Sesudah shifting: 1111111010000000000111111111 1011001010000000000001011010
# Sebelum shifting: 1111111010000000000111111111 1011001010000000000001011010
# Sesudah shifting: 1111101000000000011111111111 1100101000000000000101101010
# Sebelum shifting: 1111101000000000011111111111 1100101000000000000101101010
# Sesudah shifting: 1110100000000001111111111111 0010100000000000010110101011
# Sebelum shifting: 1110100000000001111111111111 0010100000000000010110101011
# Sesudah shifting: 1010000000000111111111111111 1010000000000001011010101100
# Sebelum shifting: 1010000000000111111111111111 1010000000000001011010101100
# Sesudah shifting: 1000000000011111111111111110 1000000000000101101010110010
# Sebelum shifting: 1000000000011111111111111110 1000000000000101101010110010
# Sesudah shifting: 0000000001111111111111111010 0000000000010110101011001010
# Sebelum shifting: 0000000001111111111111111010 0000000000010110101011001010
# Sesudah shifting: 0000000011111111111111110100 0000000000101101010110010100
# Data Being Encrypted:       DC32AA02D5BEDEB3
# After Initial Permutation:  51F37190F5A665EE
#                      Left Half                        Right Half                       Sub Key
# Sebelum di XNOR kan: 01010001111100110111000110010000 00101011010100010110101010010010
# Hasil setelah XNOR: 10000101010111011110010011111101
# Round:  1   11110101101001100110010111101110   10000101010111011110010011111101   111000001011111001100110100010011101000001000000
# Sebelum di XNOR kan: 11110101101001100110010111101110 11011110111010000100001011111111
# Hasil setelah XNOR: 11010100101100011101100011101110
# Round:  2   10000101010111011110010011111101   11010100101100011101100011101110   111100001011011001110110010110010000101000111000
# Sebelum di XNOR kan: 10000101010111011110010011111101 10000001000100001110001110010001
# Hasil setelah XNOR: 11111011101100101111100010010011
# Sebelum shifting: 0000000011111111111111110100 0000000000101101010110010100
# Sesudah shifting: 0000000111111111111111101000 0000000001011010101100101000
# Sebelum shifting: 0000000111111111111111101000 0000000001011010101100101000
# Sesudah shifting: 0000001111111111111111010000 0000000010110101011001010000
# Sebelum shifting: 0000001111111111111111010000 0000000010110101011001010000
# Sesudah shifting: 0000111111111111111101000000 0000001011010101100101000000
# Sebelum shifting: 0000111111111111111101000000 0000001011010101100101000000
# Sesudah shifting: 0011111111111111110100000000 0000101101010110010100000000
# Sebelum shifting: 0011111111111111110100000000 0000101101010110010100000000
# Sesudah shifting: 1111111111111111010000000000 0010110101011001010000000000
# Sebelum shifting: 1111111111111111010000000000 0010110101011001010000000000
# Sesudah shifting: 1111111111111101000000000011 1011010101100101000000000000
# Sebelum shifting: 1111111111111101000000000011 1011010101100101000000000000
# Sesudah shifting: 1111111111110100000000001111 1101010110010100000000000010
# Sebelum shifting: 1111111111110100000000001111 1101010110010100000000000010
# Sesudah shifting: 1111111111010000000000111111 0101011001010000000000001011
# Sebelum shifting: 1111111111010000000000111111 0101011001010000000000001011
# Sesudah shifting: 1111111110100000000001111111 1010110010100000000000010110
# Sebelum shifting: 1111111110100000000001111111 1010110010100000000000010110
# Sesudah shifting: 1111111010000000000111111111 1011001010000000000001011010
# Sebelum shifting: 1111111010000000000111111111 1011001010000000000001011010
# Sesudah shifting: 1111101000000000011111111111 1100101000000000000101101010
# Sebelum shifting: 1111101000000000011111111111 1100101000000000000101101010
# Sesudah shifting: 1110100000000001111111111111 0010100000000000010110101011
# Sebelum shifting: 1110100000000001111111111111 0010100000000000010110101011
# Sesudah shifting: 1010000000000111111111111111 1010000000000001011010101100
# Sebelum shifting: 1010000000000111111111111111 1010000000000001011010101100
# Sesudah shifting: 1000000000011111111111111110 1000000000000101101010110010
# Sebelum shifting: 1000000000011111111111111110 1000000000000101101010110010
# Sesudah shifting: 0000000001111111111111111010 0000000000010110101011001010
# Sebelum shifting: 0000000001111111111111111010 0000000000010110101011001010
# Sesudah shifting: 0000000011111111111111110100 0000000000101101010110010100
# Data Being Encrypted:       943847BCCB54EE30
# After Initial Permutation:  74AB6D1459CA5A54
#                      Left Half                        Right Half                       Sub Key
# Sebelum di XNOR kan: 01110100101010110110110100010100 01000010001001110100101100110100
# Hasil setelah XNOR: 11001001011100111101100111011111
# Round:  1   01011001110010100101101001010100   11001001011100111101100111011111   111000001011111001100110100010011101000001000000
# Sebelum di XNOR kan: 01011001110010100101101001010100 01010011111111010101101001101100
# Hasil setelah XNOR: 11110101110010001111111111000111
# Round:  2   11001001011100111101100111011111   11110101110010001111111111000111   111100001011011001110110010110010000101000111000
# Sebelum di XNOR kan: 11001001011100111101100111011111 11101011111111111001111110001101
# Hasil setelah XNOR: 11011101011100111011100110101101
# Round:  3   11110101110010001111111111000111   11011101011100111011100110101101   111001001101011001110110000100010101100000011000
# Sebelum di XNOR kan: 11110101110010001111111111000111 10010001111011001100010100100100
# Hasil setelah XNOR: 10011011110110111100010100011100
# Round:  4   11011101011100111011100110101101   10011011110110111100010100011100   111001101101001101110110000000010011000000110100
# Sebelum di XNOR kan: 11011101011100111011100110101101 01000000001101010100100110001000
# Hasil setelah XNOR: 01100010101110010000111111011010
# Round:  5   10011011110110111100010100011100   01100010101110010000111111011010   101011101101001101110011101000010010100010100100
# Sebelum di XNOR kan: 10011011110110111100010100011100 11010010100001000000110110011011
# Hasil setelah XNOR: 10110110101000000011011101111000
# Round:  6   01100010101110010000111111011010   10110110101000000011011101111000   101011110101001101111011001000000000101010010111
# Sebelum di XNOR kan: 01100010101110010000111111011010 01101000111100010101111000111111
# Hasil setelah XNOR: 11110101101101111010111000011010
# Round:  7   10110110101000000011011101111000   11110101101101111010111000011010   101011110101001111011001000101110000000010010111
# Sebelum di XNOR kan: 10110110101000000011011101111000 00000001110000100001001010101011
# Hasil setelah XNOR: 01001000100111011101101000101100
# Round:  8   11110101101101111010111000011010   01001000100111011101101000101100   000111110101101111011001000001110000000111000001
# Sebelum di XNOR kan: 11110101101101111010111000011010 00000110010010011101110011000110
# Hasil setelah XNOR: 00001100000000011000110100100011
# Round:  9   01001000100111011101101000101100   00001100000000011000110100100011   001111110100100111011001011101000010001010000010
# Sebelum di XNOR kan: 01001000100111011101101000101100 01110100000001100110011110011110
# Hasil setelah XNOR: 11000011011001000100001001001101
# Round:  10   00001100000000011000110100100011   11000011011001000100001001001101   000111110110100110011101011101000000000001001011
# Sebelum di XNOR kan: 00001100000000011000110100100011 11101000000100000100011111100000
# Hasil setelah XNOR: 00011011111011100011010100111100
# Round:  11   11000011011001000100001001001101   00011011111011100011010100111100   000111110010110110011101000001101011000001001010
# Sebelum di XNOR kan: 11000011011001000100001001001101 11100010101111000000101100000110
# Hasil setelah XNOR: 11011110001001111011011010110100
# Round:  12   00011011111011100011010100111100   11011110001001111011011010110100   010111110010110010101101001001001011010101100000
# Sebelum di XNOR kan: 00011011111011100011010100111100 10011010011001110100101100000010
# Hasil setelah XNOR: 01111110011101101000000111000001
# Round:  13   11011110001001111011011010110100   01111110011101101000000111000001   110110111010110010101100001010001000110001100010
# Sebelum di XNOR kan: 11011110001001111011011010110100 10011001000001101010000111110001
# Hasil setelah XNOR: 10111000110111101110100010111010
# Round:  14   01111110011101101000000111000001   10111000110111101110100010111010   110110001010111010101110010011001100110000010010
# Sebelum di XNOR kan: 01111110011101101000000111000001 10000001011101101000001000111100
# Hasil setelah XNOR: 00000000111111111111110000000010
# Round:  15   10111000110111101110100010111010   00000000111111111111110000000010   111100001011111000101110000011010100010001011000
# Sebelum di XNOR kan: 10111000110111101110100010111010 01000000001000011110110110111000
# Hasil setelah XNOR: 00000111000000001111101011111101
# Round:  16   00000000111111111111110000000010   00000111000000001111101011111101   111100001011111010100110110000000001111000110000
# Plain Text = kriptografi
#
# Pilihlah salah satu dari pilihan berikut:
# 1. Encrypt
# 2. Decrypt
# 3. Keluar dari program
