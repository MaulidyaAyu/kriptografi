# %% [markdown]
# <a href="https://colab.research.google.com/github/MaulidyaAyu/kriptografi/blob/main/DES%20Maulidya%3A%20XNOR%20%2B%20shifted%20ke%20kanan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Encryption Standard (DES) - Rounds 16

# %%
# DES Enkripsi

# Function teks ke binary
def text_to_binary(text):
    binary_result = ' '.join(format(ord(char), '08b') for char in text)
    return binary_result.replace(' ', '')

# Function teks ke hexa
def text_to_hex(text):
    hex_result = ''.join(hex(ord(char))[2:] for char in text)
    return hex_result.upper()

#function hexa ke teks
def hex_to_text(hex_string):
    text_result = ''.join(chr(int(hex_string[i:i+2], 16)) for i in range(0, len(hex_string), 2))
    return text_result

# fungsi untuk mengubah binary ke hexa
def bin_to_hex(binary, length):
    bin_to_hex = {"0000" : '0',"0001" : '1',"0010" : '2',"0011" : '3',"0100" : '4',"0101" : '5',"0110" : '6',"0111" : '7',
                  "1000" : '8',"1001" : '9',"1010" : 'A',"1011" : 'B',"1100" : 'C',"1101" : 'D',"1110" : 'E',"1111" : 'F'}
    store = ''
    for i in range(0,length,4):
        store += bin_to_hex[str(binary[i:(i+4)])]
    return store

# fungsi untuk mengubah hexa ke binary
def hex_to_binary(binary, length):
    hex_to_bin = {'0' : "0000", '1' : "0001",'2' : "0010",'3' : "0011",'4' : "0100",'5' : "0101",'6' : "0110",'7' : "0111",
                '8' : "1000",'9' : "1001",'A' : "1010",'B' : "1011",'C' : "1100",'D' : "1101",'E' : "1110",'F' : "1111" }
    store = ''
    for i in range(0,length):
        store += hex_to_bin[str(binary[i])]
    return store

##############################################################################################
############################          YANG DIRUBAH             ###############################
##############################################################################################

# function xnor
def xnor(a,b):
    store = ''
    for i in range(len(a)):
        store += str(int(not(int(a[i]) ^ int(b[i]))))
    return store

# mengubah binary yang tipe datanya string ke int agar bisa diolah nilainya
def bin_to_int(binary_string):
    length = len(binary_string) - 1
    number = 0
    for bin in range(length + 1):
        number += int(binary_string[bin]) * (2 ** (length - bin))
    return number

# mengubah integer ke binary
def int_to_bin(integer):
    return bin(integer)[2:]


##############################################################################################
############################          YANG DIRUBAH             ###############################
##############################################################################################

# digunakan untuk melakukan shifting sesuai banyaknya iterasi
def shifted(bits, shift):
    return bits[-shift:] + bits[:-shift]

# 00010001
# contoh shift = 2
#  bits[shift:] = bits[2:]
# mengambil nilai bits selain 2 didepan, 00
# bits[:shift] = bits[:2]
# mengambil nilai bits hanya nilai 2 dari depan, 000100
# return  00 + 000100


#   Defines A Function For Permuting Lists of Binary Using Permutation Lookup Tables
def permute(data, permutation_table, length_of_output):
    permutation = ''
    for i in range(length_of_output):
        permutation += data[permutation_table[i] - 1]
    return permutation

# The Inital and Final Permuttions For The DES Algorithm
def IP(data):
    initial_perm = [58, 50, 42, 34, 26, 18, 10, 2, 60, 52, 44, 36, 28, 20, 12, 4,62, 54, 46, 38, 30, 22, 14, 6, 64, 56, 48, 40, 32, 24, 16, 8,
                    57, 49, 41, 33, 25, 17, 9, 1, 59, 51, 43, 35, 27, 19, 11, 3, 61, 53, 45, 37, 29, 21, 13, 5, 63, 55, 47, 39, 31, 23, 15, 7]
    return permute(data, initial_perm, 64)
def IP_Inverse(data):
    inverse_perm = [40, 8, 48, 16, 56, 24, 64, 32, 39, 7, 47, 15, 55, 23, 63, 31, 38, 6, 46, 14, 54, 22, 62, 30, 37, 5, 45, 13, 53, 21, 61, 29,
                    36, 4, 44, 12, 52, 20, 60, 28, 35, 3, 43, 11, 51, 19, 59, 27, 34, 2, 42, 10, 50, 18, 58, 26, 33, 1, 41, 9, 49, 17, 57, 25 ]
    return permute(data, inverse_perm, 64)


#  Inner functions for bit manipulations in the Feistel Function Stages
def f_expansion(bits):
    # This permutation expands the input to 48 bits and provides a layer of 'confusion'
    expansion_perm = [32, 1 , 2 , 3 , 4 , 5 , 4 , 5, 6 , 7 , 8 , 9 , 8 , 9 , 10, 11, 12, 13, 12, 13, 14, 15, 16, 17,
                      16, 17, 18, 19, 20, 21, 20, 21, 22, 23, 24, 25, 24, 25, 26, 27, 28, 29, 28, 29, 30, 31, 32, 1 ]
    return permute(bits, expansion_perm, 48)

def f_key_mixing(bits, key):
    # This function just xnor's the key into the message
    return xnor(bits, key)

def s_boxes(bits):
    # These substitution boxes are really the core of the DES algorithm, they take six input bits and maps it to 4 output bits
    #       this provides the diffusion necessary to make a secure block cipher (not that DES is secure, because it is not)
    sboxes =   [[[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7], [0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8], [4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0], [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13 ]],
                [[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10], [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5], [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15], [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9 ]],
                [[10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8], [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1], [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7], [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12 ]],
                [[7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15], [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9], [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4], [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14 ]],
                [[2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9], [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6], [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14], [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3 ]],
                [[12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11], [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8], [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6], [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13 ]],
                [[4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1], [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6], [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2], [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12 ]],
                [[13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7], [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2], [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8], [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11 ]]]
    # Split the bytes into 8 substrings, split those substrings into the outer and inner bits,
    #       and use them as indexes for the lookup in the sboxes, convert to binary and pad zeros if necessary
    substituted_string = ''
    for i in range(0,48,6):
        substring = (bits[0:48][i:i+6])
        row = bin_to_int(substring[0] + substring[5])
        column = bin_to_int(substring[1] + substring[2] + substring[3] + substring[4])
        lookup = int_to_bin(sboxes[int(i/6)][row][column])
        if len(lookup) < 4:
            lookup = ((4 - len(lookup)) * '0') + lookup
        substituted_string += lookup

    return substituted_string

# The Feistel function includes a final permutation, for added 'confusion' in each round.
def f_permute(bits):
    p_box = [16, 7, 20, 21, 29, 12, 28, 17, 1, 15, 23, 26, 5, 18, 31, 10, 2, 8, 24, 14, 32, 27, 3, 9, 19, 13, 30, 6, 22, 11, 4, 25]
    return permute(bits, p_box, 32)


# The Feistel Function Called During Encryption and Decryption
def f(bytes, key): # bytes = right_half , 32 bit
    expanded = f_expansion(bytes)
    mixed = f_key_mixing(expanded, key)
    substituted = s_boxes(mixed)
    permutation = f_permute(substituted)
    return permutation


##############################################################################################
############################          YANG DIRUBAH             ###############################
##############################################################################################
def round(left_half, right_half, key):
    print("Sebelum di XNOR kan:",  left_half, f(right_half, key))
    new_right_half = xnor(left_half, f(right_half, key))
    print("Hasil setelah XNOR:", new_right_half)
    return right_half, new_right_half


#############################################################
# The Key Schedule Generator
#   This function generates the sixteen subkeys for DES
#############################################################
def generate_keys(intitial_state): # inputan berupa hex
    # check apakah panjang bit nya 64 key
    if len(intitial_state) != 64:
      # check jika panjangnya 16 , kemungkinan menggunakan hexa dan mengubah ke binary
        if len(intitial_state) == 16:
            intitial_state = hex_to_binary(intitial_state, 16)
        else:
            return 'ERROR MESSAGE NOT PROPER SIZE'

    pc_1 = [57, 49, 41, 33, 25, 17, 9, 1, 58, 50, 42, 34, 26, 18, 10, 2, 59, 51, 43, 35, 27, 19, 11, 3, 60, 52, 44, 36,
            63, 55, 47, 39, 31, 23, 15, 7, 62, 54, 46, 38, 30, 22, 14, 6, 61, 53, 45, 37, 29, 21, 13, 5, 28, 20, 12, 4]
    pc_2 = [14, 17, 11, 24, 1, 5, 3, 28, 15, 6, 21, 10, 23, 19, 12, 4, 26, 8, 16, 7, 27, 20, 13, 2, 41,
            52, 31, 37, 47, 55, 30, 40, 51, 45, 33, 48, 44, 49, 39, 56, 34, 53, 46, 42, 50, 36, 29, 32 ]
    # di mutasi ke pc1
    permuted = permute(intitial_state, pc_1, 56)


##############################################################################################
############################          YANG DIRUBAH             ###############################
##############################################################################################
    key_schedule = []
    left_half, right_half = permuted[0:28], permuted[28:56]
    for loop in range(16):
        print("Sebelum shifting:", left_half, right_half)
        if loop in {0, 1, 8, 15}:
            left_half, right_half = shifted(left_half, 1), shifted(right_half, 1)
        else:
            left_half, right_half = shifted(left_half, 2), shifted(right_half, 2)
        print("Sesudah shifting:", left_half, right_half)

        key_schedule.append(permute((left_half + right_half), pc_2, 48))

    return key_schedule



####################################################################
#   THE MAIN ENCRYPTION FUNCTION FOR DES
#       This function encrypts a block of 64 bits using
#       a 64 bit key (this is supposed to include parity bits)
####################################################################
def encrypt(message, key):
    if len(message) != 64:
        if len(message) == 16:
            message = hex_to_binary(message, 16)
        else:
            return 'ERROR MESSAGE NOT PROPER SIZE'

    key_schedule = generate_keys(key)

    print('Data Being Encrypted: ', bin_to_hex(message, 64))
    perm = IP(message)
    print('After Initial Permutation: ', bin_to_hex(perm, 64))

    left_half, right_half = perm[0:32], perm[32:64]

    print(' ' * 20, 'Left Half  ', 'Right Half ', 'Sub Key  ')
    for loop in range(16):
        left_half, right_half = round(left_half, right_half, key_schedule[loop])
        # if loop == 15: # For Some Reason The Algorithm Doesn't Swap The Last Two Keys So This Switches Them Back
        #     buffer = left_half
        #     left_half = right_half
        #     right_half = buffer
        # print('Round: ', loop + 1, ' ', bin_to_hex(left_half, 32), ' ', bin_to_hex(right_half, 32), ' ', bin_to_hex(key_schedule[loop], 48))
        #print('Round: ', loop + 1, ' ', left_half, ' ', right_half, ' ', key_schedule[loop])
        #if loop == 15:
          #print('Round: ', "Swap", ' ', right_half, ' ', left_half, ' ', key_schedule[loop])

    cyphertext = IP_Inverse(right_half + left_half)
    return cyphertext

####################################################################
#   THE MAIN DECRYPTION FUNCTION FOR DES
#       This function decrypts a block of 64 bits using
#       a 64 bit key (this is supposed to include parity bits)
#       It is the same as encrypton algorithm but  with an upside
#       down key schedule.
####################################################################
def decrypt(message, key):
    if len(message) != 64:
        if len(message) == 16:
            message = hex_to_binary(message, 16)
        else:
            return 'ERROR MESSAGE NOT PROPER SIZE'
    key_schedule = generate_keys(key)
    print('Data Being Encrypted:      ', bin_to_hex(message, 64))
    perm = IP(message)
    print('After Initial Permutation: ', bin_to_hex(perm, 64))
    left_half, right_half = perm[0:32], perm[32:64]
    print(' ' * 20, 'Left Half  ',' ' * 20, 'Right Half ',' ' * 20, 'Sub Key  ')
    for loop in range(16):
        left_half, right_half = round(left_half, right_half, key_schedule[15 - loop])
        # if loop == 15: # For Some Reason The Algorithm Doesn't Swap The Last Two Keys So This Switches Them Back
        #     buffer = left_half
        #     left_half = right_half
        #     right_half = buffer
        # print('Round: ', loop + 1, ' ', bin_to_hex(left_half, 32), ' ', bin_to_hex(right_half, 32), ' ', bin_to_hex(key_schedule[loop], 48))
        #print('Round: ', loop + 1, ' ', left_half , ' ', right_half, ' ', key_schedule[loop] )

    cyphertext = IP_Inverse(right_half + left_half)

    return cyphertext

# Membuat teks menjadi 8 huruf dan dimasukan kedalam array
def modif_plain(par):
    while len(par) % 8 != 0:
        par += "-"
    par_arr = [par[i:i+8] for i in range(0, len(par), 8)]
    return par_arr

def modif_cipher(par):
    while len(par) % 64 != 0:
        par += "-"
    par_arr = [par[i:i+64] for i in range(0, len(par), 64)]
    return par_arr



def encrypt_print(plain , key):
  hasil_encrypt = []
  hasil_encrypt_hexa= []

  hex_key = text_to_hex(key)

  for i in plain:
    e = encrypt(text_to_binary(i), hex_key)
    encrypt_hexa =  bin_to_hex(''.join(e) , 64)
    encrypt_text =  hex_to_text(bin_to_hex(''.join(e) , 64))
    hasil_encrypt.append(e)
    hasil_encrypt_hexa.append(encrypt_hexa)


  print("Hasil enkrip dalam bentuk biner = " ,  ''.join(hasil_encrypt))
  print("Hasil enkrip dalam bentuk hexa =  " , ''.join(hasil_encrypt_hexa) )

  return hasil_encrypt

def decrypt_print(chiper , key):
  hex_key = text_to_hex(key)
  # print(cipher_modif)
  hasil_decrpyt = []
  for x in chiper:
    hasil_decrpyt.append(hex_to_text( bin_to_hex(decrypt(x, hex_key), 64)))

  print("Plain Text =" ,''.join(hasil_decrpyt).rstrip('-'))
  return hasil_decrpyt

def main():
  while True:
        print("\nPilihlah salah satu dari pilihan berikut:")
        print("1. Encrypt")
        print("2. Decrypt")
        print("3. Keluar dari program")
        choice = input("Masukkan pilihan Anda: ")

        if choice == '1':
            plain_text = input("Masukkan plain text untuk dienkripsi :  ")
            plain_modif = modif_plain(plain_text)
            key = input("Masukan key text ( 64 bit / 8 huruf ) : ")
            hasil = encrypt_print(plain_modif , key)

        elif choice == '2':
            cipher_text = input("Masukkan cipher text (dalam binary): ")
            key = input("Masukkan kunci: ")
            cipher_modif = modif_cipher(cipher_text)
            hasil = decrypt_print(cipher_modif , key)

        elif choice == '3':
            print("Terima kasih, program selesai.")
            break
        else:
            print("Pilihan tidak valid. Silakan pilih 1, 2, atau 3.")



main()
# Out:
# Pilihlah salah satu dari pilihan berikut:
# 1. Encrypt
# 2. Decrypt
# 3. Keluar dari program
# Masukkan pilihan Anda: 1
# Masukkan plain text untuk dienkripsi :  maulidya ayu ardiena
# Masukan key text ( 64 bit / 8 huruf ) : dinusian
# Sebelum shifting: 0000000011111111111111110001 1001010010001101101001101000
# Sesudah shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sebelum shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sesudah shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sebelum shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sesudah shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sebelum shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sesudah shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sebelum shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sesudah shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sebelum shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sesudah shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sebelum shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sesudah shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sebelum shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sesudah shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sebelum shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sesudah shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sebelum shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sesudah shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sebelum shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sesudah shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sebelum shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sesudah shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sebelum shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sesudah shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sebelum shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sesudah shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sebelum shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sesudah shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sebelum shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sesudah shifting: 0000000011111111111111110001 1001010010001101101001101000
# Data Being Encrypted:  6D61756C69647961
# After Initial Permutation:  FF442DD700FF5900
#                      Left Half   Right Half  Sub Key
# Sebelum di XNOR kan: 11111111010001000010110111010111 01010100011101000101010100111100
# Hasil setelah XNOR: 01010100110011111000011100010100
# Sebelum di XNOR kan: 00000000111111110101100100000000 10111010101100001111001010110101
# Hasil setelah XNOR: 01000101101100000101010001001010
# Sebelum di XNOR kan: 01010100110011111000011100010100 10110010101100111100101111101011
# Hasil setelah XNOR: 00011001100000111011001100000000
# Sebelum di XNOR kan: 01000101101100000101010001001010 01111001010000001100111010011101
# Hasil setelah XNOR: 11000011000011110110010100101000
# Sebelum di XNOR kan: 00011001100000111011001100000000 11011010011001011011100010101111
# Hasil setelah XNOR: 00111100000110011111010001010000
# Sebelum di XNOR kan: 11000011000011110110010100101000 10101100101001101111100001010111
# Hasil setelah XNOR: 10010000010101100110001010000000
# Sebelum di XNOR kan: 00111100000110011111010001010000 01011010010101011111001010101000
# Hasil setelah XNOR: 10011001101100111111100100000111
# Sebelum di XNOR kan: 10010000010101100110001010000000 10100011100001100011110001001010
# Hasil setelah XNOR: 11001100001011111010000100110101
# Sebelum di XNOR kan: 10011001101100111111100100000111 00111011101101101011111011001100
# Hasil setelah XNOR: 01011101111110101011100000110100
# Sebelum di XNOR kan: 11001100001011111010000100110101 01000010000011001111111100000111
# Hasil setelah XNOR: 01110001110111001010000111001101
# Sebelum di XNOR kan: 01011101111110101011100000110100 00100010111011010110011110011001
# Hasil setelah XNOR: 10000000111010000010000001010010
# Sebelum di XNOR kan: 01110001110111001010000111001101 00000111100111111011010010111100
# Hasil setelah XNOR: 10001001101111001110101010001110
# Sebelum di XNOR kan: 10000000111010000010000001010010 10110011110110110110001100111111
# Hasil setelah XNOR: 11001100110011001011110010010010
# Sebelum di XNOR kan: 10001001101111001110101010001110 11001011001101011100111100100010
# Hasil setelah XNOR: 10111101011101101101101001010011
# Sebelum di XNOR kan: 11001100110011001011110010010010 00001011100101101000001111010011
# Hasil setelah XNOR: 00111000101001011100000010111110
# Sebelum di XNOR kan: 10111101011101101101101001010011 00100011110000001100100110100011
# Hasil setelah XNOR: 01100001010010011110110000001111
# Sebelum shifting: 0000000011111111111111110001 1001010010001101101001101000
# Sesudah shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sebelum shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sesudah shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sebelum shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sesudah shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sebelum shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sesudah shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sebelum shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sesudah shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sebelum shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sesudah shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sebelum shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sesudah shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sebelum shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sesudah shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sebelum shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sesudah shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sebelum shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sesudah shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sebelum shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sesudah shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sebelum shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sesudah shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sebelum shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sesudah shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sebelum shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sesudah shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sebelum shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sesudah shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sebelum shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sesudah shifting: 0000000011111111111111110001 1001010010001101101001101000
# Data Being Encrypted:  2061797520617264
# After Initial Permutation:  EE4C882E00FF0440
#                      Left Half   Right Half  Sub Key
# Sebelum di XNOR kan: 11101110010011001000100000101110 01110110011100000101010100111101
# Hasil setelah XNOR: 01100111110000110010001011101100
# Sebelum di XNOR kan: 00000000111111110000010001000000 11011000010000100111110011101110
# Hasil setelah XNOR: 00100111010000101000011101010001
# Sebelum di XNOR kan: 01100111110000110010001011101100 01000110001011001100111011111011
# Hasil setelah XNOR: 11011110000100000001001111101000
# Sebelum di XNOR kan: 00100111010000101000011101010001 11110011101110001100010100100100
# Hasil setelah XNOR: 00101011000001011011110110001010
# Sebelum di XNOR kan: 11011110000100000001001111101000 00101001000111000101011111100000
# Hasil setelah XNOR: 00001000111100111011101111110111
# Sebelum di XNOR kan: 00101011000001011011110110001010 01100011110000110010000100010110
# Hasil setelah XNOR: 10110111001110010110001101100011
# Sebelum di XNOR kan: 00001000111100111011101111110111 00100110101000000100010011001101
# Hasil setelah XNOR: 11010001101011000000000011000101
# Sebelum di XNOR kan: 10110111001110010110001101100011 01111001000100100111000100001010
# Hasil setelah XNOR: 00110001110101001110110110010110
# Sebelum di XNOR kan: 11010001101011000000000011000101 10001000010010101100011000011010
# Hasil setelah XNOR: 10100110000110010011100100100000
# Sebelum di XNOR kan: 00110001110101001110110110010110 11001111101110111011101100111111
# Hasil setelah XNOR: 00000001100100001010100101010110
# Sebelum di XNOR kan: 10100110000110010011100100100000 01000101000000001110011010101001
# Hasil setelah XNOR: 00011100111001100010000001110110
# Sebelum di XNOR kan: 00000001100100001010100101010110 11000001010101001111101010101011
# Hasil setelah XNOR: 00111111001110111010110000000010
# Sebelum di XNOR kan: 00011100111001100010000001110110 01001110010101110100110110000001
# Hasil setelah XNOR: 10101101010011101001001000001000
# Sebelum di XNOR kan: 00111111001110111010110000000010 00001011101001100010001101011101
# Hasil setelah XNOR: 11001011011000100111000010100000
# Sebelum di XNOR kan: 10101101010011101001001000001000 01001100011111011000111100011110
# Hasil setelah XNOR: 00011110110011001110001011101001
# Sebelum di XNOR kan: 11001011011000100111000010100000 11011010011100001001100110110001
# Hasil setelah XNOR: 11101110111011010001011011101110
# Sebelum shifting: 0000000011111111111111110001 1001010010001101101001101000
# Sesudah shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sebelum shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sesudah shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sebelum shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sesudah shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sebelum shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sesudah shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sebelum shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sesudah shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sebelum shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sesudah shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sebelum shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sesudah shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sebelum shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sesudah shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sebelum shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sesudah shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sebelum shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sesudah shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sebelum shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sesudah shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sebelum shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sesudah shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sebelum shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sesudah shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sebelum shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sesudah shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sebelum shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sesudah shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sebelum shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sesudah shifting: 0000000011111111111111110001 1001010010001101101001101000
# Data Being Encrypted:  69656E612D2D2D2D
# After Initial Permutation:  0F00F6FB00FFF504
#                      Left Half   Right Half  Sub Key
# Sebelum di XNOR kan: 00001111000000001111011011111011 01111100000101000110010100011100
# Hasil setelah XNOR: 10001100111010110110110000011000
# Sebelum di XNOR kan: 00000000111111111111010100000100 00011110110111000100011101111100
# Hasil setelah XNOR: 11100001110111000100110110000111
# Sebelum di XNOR kan: 10001100111010110110110000011000 01001101110110101110011011101000
# Hasil setelah XNOR: 00111110110011100111010100001111
# Sebelum di XNOR kan: 11100001110111000100110110000111 00001010111101110100010101011001
# Hasil setelah XNOR: 00010100110101001111011100100001
# Sebelum di XNOR kan: 00111110110011100111010100001111 01011100010000110100001101111000
# Hasil setelah XNOR: 10011101011100101100100110001000
# Sebelum di XNOR kan: 00010100110101001111011100100001 00000010100110100011000001101011
# Hasil setelah XNOR: 11101001101100010011100010110101
# Sebelum di XNOR kan: 10011101011100101100100110001000 00011111010001001001101101100010
# Hasil setelah XNOR: 01111101110010011010110100010101
# Sebelum di XNOR kan: 11101001101100010011100010110101 11011101100111101101111000100001
# Hasil setelah XNOR: 11001011110100000001100101101011
# Sebelum di XNOR kan: 01111101110010011010110100010101 10001010111000101110011010000001
# Hasil setelah XNOR: 00001000110101001011010001101011
# Sebelum di XNOR kan: 11001011110100000001100101101011 00111101001110011110101110001111
# Hasil setelah XNOR: 00001001000101100000110100011011
# Sebelum di XNOR kan: 00001000110101001011010001101011 10101001011110000111011100100111
# Hasil setelah XNOR: 01011110010100110011110010110011
# Sebelum di XNOR kan: 00001001000101100000110100011011 10011101011010110100100001110010
# Hasil setelah XNOR: 01101011100000101011101010010110
# Sebelum di XNOR kan: 01011110010100110011110010110011 01110110000111000000001000100001
# Hasil setelah XNOR: 11010111101100001100000101101101
# Sebelum di XNOR kan: 01101011100000101011101010010110 00111101001001001111001001010000
# Hasil setelah XNOR: 10101001010110011011011100111001
# Sebelum di XNOR kan: 11010111101100001100000101101101 01010010111111101111110110101000
# Hasil setelah XNOR: 01111010101100011100001100111010
# Sebelum di XNOR kan: 10101001010110011011011100111001 00101001110010100010011010010110
# Hasil setelah XNOR: 01111111011011000110111001010000
# Hasil enkrip dalam bentuk biner =  011100010000001100100111100101111000001011100110010111000010111000010010110011011111010111110011100001000101101101111011011110110110100011001110010101001101011011100011111101101101110100101000
# Hasil enkrip dalam bentuk hexa =   7103279782E65C2E12CDF5F3845B7B7B68CE54D6E3F6DD28
#
# Pilihlah salah satu dari pilihan berikut:
# 1. Encrypt
# 2. Decrypt
# 3. Keluar dari program
# Masukkan pilihan Anda: 2
# Masukkan cipher text (dalam binary): 011100010000001100100111100101111000001011100110010111000010111000010010110011011111010111110011100001000101101101111011011110110110100011001110010101001101011011100011111101101101110100101000
# Masukkan kunci: dinusian
# Sebelum shifting: 0000000011111111111111110001 1001010010001101101001101000
# Sesudah shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sebelum shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sesudah shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sebelum shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sesudah shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sebelum shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sesudah shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sebelum shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sesudah shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sebelum shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sesudah shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sebelum shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sesudah shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sebelum shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sesudah shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sebelum shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sesudah shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sebelum shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sesudah shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sebelum shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sesudah shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sebelum shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sesudah shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sebelum shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sesudah shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sebelum shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sesudah shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sebelum shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sesudah shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sebelum shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sesudah shifting: 0000000011111111111111110001 1001010010001101101001101000
# Data Being Encrypted:       7103279782E65C2E
# After Initial Permutation:  6149EC0F38A5C0BE
#                      Left Half                        Right Half                       Sub Key
# Sebelum di XNOR kan: 01100001010010011110110000001111 00100011110000001100100110100011
# Hasil setelah XNOR: 10111101011101101101101001010011
# Sebelum di XNOR kan: 00111000101001011100000010111110 00001011100101101000001111010011
# Hasil setelah XNOR: 11001100110011001011110010010010
# Sebelum di XNOR kan: 10111101011101101101101001010011 11001011001101011100111100100010
# Hasil setelah XNOR: 10001001101111001110101010001110
# Sebelum di XNOR kan: 11001100110011001011110010010010 10110011110110110110001100111111
# Hasil setelah XNOR: 10000000111010000010000001010010
# Sebelum di XNOR kan: 10001001101111001110101010001110 00000111100111111011010010111100
# Hasil setelah XNOR: 01110001110111001010000111001101
# Sebelum di XNOR kan: 10000000111010000010000001010010 00100010111011010110011110011001
# Hasil setelah XNOR: 01011101111110101011100000110100
# Sebelum di XNOR kan: 01110001110111001010000111001101 01000010000011001111111100000111
# Hasil setelah XNOR: 11001100001011111010000100110101
# Sebelum di XNOR kan: 01011101111110101011100000110100 00111011101101101011111011001100
# Hasil setelah XNOR: 10011001101100111111100100000111
# Sebelum di XNOR kan: 11001100001011111010000100110101 10100011100001100011110001001010
# Hasil setelah XNOR: 10010000010101100110001010000000
# Sebelum di XNOR kan: 10011001101100111111100100000111 01011010010101011111001010101000
# Hasil setelah XNOR: 00111100000110011111010001010000
# Sebelum di XNOR kan: 10010000010101100110001010000000 10101100101001101111100001010111
# Hasil setelah XNOR: 11000011000011110110010100101000
# Sebelum di XNOR kan: 00111100000110011111010001010000 11011010011001011011100010101111
# Hasil setelah XNOR: 00011001100000111011001100000000
# Sebelum di XNOR kan: 11000011000011110110010100101000 01111001010000001100111010011101
# Hasil setelah XNOR: 01000101101100000101010001001010
# Sebelum di XNOR kan: 00011001100000111011001100000000 10110010101100111100101111101011
# Hasil setelah XNOR: 01010100110011111000011100010100
# Sebelum di XNOR kan: 01000101101100000101010001001010 10111010101100001111001010110101
# Hasil setelah XNOR: 00000000111111110101100100000000
# Sebelum di XNOR kan: 01010100110011111000011100010100 01010100011101000101010100111100
# Hasil setelah XNOR: 11111111010001000010110111010111
# Sebelum shifting: 0000000011111111111111110001 1001010010001101101001101000
# Sesudah shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sebelum shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sesudah shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sebelum shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sesudah shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sebelum shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sesudah shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sebelum shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sesudah shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sebelum shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sesudah shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sebelum shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sesudah shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sebelum shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sesudah shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sebelum shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sesudah shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sebelum shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sesudah shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sebelum shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sesudah shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sebelum shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sesudah shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sebelum shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sesudah shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sebelum shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sesudah shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sebelum shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sesudah shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sebelum shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sesudah shifting: 0000000011111111111111110001 1001010010001101101001101000
# Data Being Encrypted:       12CDF5F3845B7B7B
# After Initial Permutation:  EEED16EE1ECCE2E9
#                      Left Half                        Right Half                       Sub Key
# Sebelum di XNOR kan: 11101110111011010001011011101110 11011010011100001001100110110001
# Hasil setelah XNOR: 11001011011000100111000010100000
# Sebelum di XNOR kan: 00011110110011001110001011101001 01001100011111011000111100011110
# Hasil setelah XNOR: 10101101010011101001001000001000
# Sebelum di XNOR kan: 11001011011000100111000010100000 00001011101001100010001101011101
# Hasil setelah XNOR: 00111111001110111010110000000010
# Sebelum di XNOR kan: 10101101010011101001001000001000 01001110010101110100110110000001
# Hasil setelah XNOR: 00011100111001100010000001110110
# Sebelum di XNOR kan: 00111111001110111010110000000010 11000001010101001111101010101011
# Hasil setelah XNOR: 00000001100100001010100101010110
# Sebelum di XNOR kan: 00011100111001100010000001110110 01000101000000001110011010101001
# Hasil setelah XNOR: 10100110000110010011100100100000
# Sebelum di XNOR kan: 00000001100100001010100101010110 11001111101110111011101100111111
# Hasil setelah XNOR: 00110001110101001110110110010110
# Sebelum di XNOR kan: 10100110000110010011100100100000 10001000010010101100011000011010
# Hasil setelah XNOR: 11010001101011000000000011000101
# Sebelum di XNOR kan: 00110001110101001110110110010110 01111001000100100111000100001010
# Hasil setelah XNOR: 10110111001110010110001101100011
# Sebelum di XNOR kan: 11010001101011000000000011000101 00100110101000000100010011001101
# Hasil setelah XNOR: 00001000111100111011101111110111
# Sebelum di XNOR kan: 10110111001110010110001101100011 01100011110000110010000100010110
# Hasil setelah XNOR: 00101011000001011011110110001010
# Sebelum di XNOR kan: 00001000111100111011101111110111 00101001000111000101011111100000
# Hasil setelah XNOR: 11011110000100000001001111101000
# Sebelum di XNOR kan: 00101011000001011011110110001010 11110011101110001100010100100100
# Hasil setelah XNOR: 00100111010000101000011101010001
# Sebelum di XNOR kan: 11011110000100000001001111101000 01000110001011001100111011111011
# Hasil setelah XNOR: 01100111110000110010001011101100
# Sebelum di XNOR kan: 00100111010000101000011101010001 11011000010000100111110011101110
# Hasil setelah XNOR: 00000000111111110000010001000000
# Sebelum di XNOR kan: 01100111110000110010001011101100 01110110011100000101010100111101
# Hasil setelah XNOR: 11101110010011001000100000101110
# Sebelum shifting: 0000000011111111111111110001 1001010010001101101001101000
# Sesudah shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sebelum shifting: 1000000001111111111111111000 0100101001000110110100110100
# Sesudah shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sebelum shifting: 0100000000111111111111111100 0010010100100011011010011010
# Sesudah shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sebelum shifting: 0001000000001111111111111111 1000100101001000110110100110
# Sesudah shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sebelum shifting: 1100010000000011111111111111 1010001001010010001101101001
# Sesudah shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sebelum shifting: 1111000100000000111111111111 0110100010010100100011011010
# Sesudah shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sebelum shifting: 1111110001000000001111111111 1001101000100101001000110110
# Sesudah shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sebelum shifting: 1111111100010000000011111111 1010011010001001010010001101
# Sesudah shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sebelum shifting: 1111111111000100000000111111 0110100110100010010100100011
# Sesudah shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sebelum shifting: 1111111111100010000000011111 1011010011010001001010010001
# Sesudah shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sebelum shifting: 1111111111111000100000000111 0110110100110100010010100100
# Sesudah shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sebelum shifting: 1111111111111110001000000001 0001101101001101000100101001
# Sesudah shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sebelum shifting: 0111111111111111100010000000 0100011011010011010001001010
# Sesudah shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sebelum shifting: 0001111111111111111000100000 1001000110110100110100010010
# Sesudah shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sebelum shifting: 0000011111111111111110001000 1010010001101101001101000100
# Sesudah shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sebelum shifting: 0000000111111111111111100010 0010100100011011010011010001
# Sesudah shifting: 0000000011111111111111110001 1001010010001101101001101000
# Data Being Encrypted:       68CE54D6E3F6DD28
# After Initial Permutation:  7F6C6E507AB1C33A
#                      Left Half                        Right Half                       Sub Key
# Sebelum di XNOR kan: 01111111011011000110111001010000 00101001110010100010011010010110
# Hasil setelah XNOR: 10101001010110011011011100111001
# Sebelum di XNOR kan: 01111010101100011100001100111010 01010010111111101111110110101000
# Hasil setelah XNOR: 11010111101100001100000101101101
# Sebelum di XNOR kan: 10101001010110011011011100111001 00111101001001001111001001010000
# Hasil setelah XNOR: 01101011100000101011101010010110
# Sebelum di XNOR kan: 11010111101100001100000101101101 01110110000111000000001000100001
# Hasil setelah XNOR: 01011110010100110011110010110011
# Sebelum di XNOR kan: 01101011100000101011101010010110 10011101011010110100100001110010
# Hasil setelah XNOR: 00001001000101100000110100011011
# Sebelum di XNOR kan: 01011110010100110011110010110011 10101001011110000111011100100111
# Hasil setelah XNOR: 00001000110101001011010001101011
# Sebelum di XNOR kan: 00001001000101100000110100011011 00111101001110011110101110001111
# Hasil setelah XNOR: 11001011110100000001100101101011
# Sebelum di XNOR kan: 00001000110101001011010001101011 10001010111000101110011010000001
# Hasil setelah XNOR: 01111101110010011010110100010101
# Sebelum di XNOR kan: 11001011110100000001100101101011 11011101100111101101111000100001
# Hasil setelah XNOR: 11101001101100010011100010110101
# Sebelum di XNOR kan: 01111101110010011010110100010101 00011111010001001001101101100010
# Hasil setelah XNOR: 10011101011100101100100110001000
# Sebelum di XNOR kan: 11101001101100010011100010110101 00000010100110100011000001101011
# Hasil setelah XNOR: 00010100110101001111011100100001
# Sebelum di XNOR kan: 10011101011100101100100110001000 01011100010000110100001101111000
# Hasil setelah XNOR: 00111110110011100111010100001111
# Sebelum di XNOR kan: 00010100110101001111011100100001 00001010111101110100010101011001
# Hasil setelah XNOR: 11100001110111000100110110000111
# Sebelum di XNOR kan: 00111110110011100111010100001111 01001101110110101110011011101000
# Hasil setelah XNOR: 10001100111010110110110000011000
# Sebelum di XNOR kan: 11100001110111000100110110000111 00011110110111000100011101111100
# Hasil setelah XNOR: 00000000111111111111010100000100
# Sebelum di XNOR kan: 10001100111010110110110000011000 01111100000101000110010100011100
# Hasil setelah XNOR: 00001111000000001111011011111011
# Plain Text = maulidya ayu ardiena
#
# Pilihlah salah satu dari pilihan berikut:
# 1. Encrypt
# 2. Decrypt
# 3. Keluar dari program
# Masukkan pilihan Anda: 3
# Terima kasih, program selesai.
